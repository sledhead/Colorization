# %%
#@title ◢ Git clone and install DeOldify
# %cd /content/
#!git clone https://github.com/jantic/DeOldify.git DeOldify 
# !git clone https://github.com/styler00dollar/Colab-DeOldify DeOldify
# %cd DeOldify
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
#choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)

import torch

if not torch.cuda.is_available():
    print('GPU not available.')
# !pip install -r colab_requirements.txt
import fastai
from deoldify.visualize import *
# !mkdir 'models'

# !wget https://deepai-opensource-codebases-models.s3-us-west-2.amazonaws.com/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth
# !wget https://www.dropbox.com/s/usf7uifrctqw9rl/ColorizeStable_gen.pth?dl=0 -O ./models/ColorizeStable_gen.pth
# !wget https://media.githubusercontent.com/media/jantic/DeOldify/master/resource_images/watermark.png -O ./resource_images/watermark.png

colorizer = get_image_colorizer(artistic=False)
# Out:
# /content
# Cloning into 'DeOldify'...
# remote: Enumerating objects: 2208, done.
# remote: Total 2208 (delta 0), reused 0 (delta 0), pack-reused 2208
# Receiving objects: 100% (2208/2208), 104.73 MiB | 16.72 MiB/s, done.
# Resolving deltas: 100% (975/975), done.
# /content/DeOldify
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 214 kB 35.3 MB/s
# ...
#      |████████████████████████████████| 129 kB 67.2 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 53.3 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 55.5 MB/s
# ...
#      |████████████████████████████████| 355 kB 65.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 9.0 MB/s
# ...
#      |████████████████████████████████| 423 kB 79.2 MB/s
# ...
#      |████████████████████████████████| 360 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 58.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 4.0 MB/s
# ...

# %%
# !ls -l
# Out:
# total 436
# -rw-r--r-- 1 root root  2564 Dec 19 07:55  app.py
# -rw-r--r-- 1 root root  3472 Dec 19 07:55  app_utils.py
# -rw-r--r-- 1 root root  2153 Dec 19 07:55  app-video.py
# -rw-r--r-- 1 root root 14809 Dec 19 07:55 'Colab-DeOldify-(Original+Anime).ipynb'
# -rw-r--r-- 1 root root   126 Dec 19 07:55  colab_requirements.txt
# -rw-r--r-- 1 root root  7379 Dec 19 07:55  ColorFIDBenchmarkArtistic.ipynb
# -rw-r--r-- 1 root root 15025 Dec 19 07:55  ColorizeTrainingArtistic.ipynb
# -rw-r--r-- 1 root root 15033 Dec 19 07:55  ColorizeTrainingStable.ipynb
# -rw-r--r-- 1 root root 18892 Dec 19 07:55  ColorizeTrainingStableLargeBatch.ipynb
# -rw-r--r-- 1 root root 11991 Dec 19 07:55  ColorizeTrainingVideo.ipynb
# -rw-r--r-- 1 root root 27053 Dec 19 07:55  ColorizeTrainingWandb.ipynb
# drwxr-xr-x 3 root root  4096 Dec 19 07:55  deoldify
# -rw-r--r-- 1 root root   973 Dec 19 07:55  Dockerfile
# -rw-r--r-- 1 root root   444 Dec 19 07:55  Dockerfile-api
# ...

# %%
# !wget https://m.media-amazon.com/images/I/71h3KoyIMDL._AC_UF894,1000_QL80_.jpg -O /content/Test_Imgs/test_img1.jpg
# Out:
# --2022-12-19 08:15:20--  https://m.media-amazon.com/images/I/71h3KoyIMDL._AC_UF894,1000_QL80_.jpg
# Resolving m.media-amazon.com (m.media-amazon.com)... 13.33.91.132, 2600:9000:20c7:6c00:1d:d7f6:39d2:2dc1, 2600:9000:20c7:5c00:1d:d7f6:39d2:2dc1, ...
# Connecting to m.media-amazon.com (m.media-amazon.com)|13.33.91.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102309 (100K) [image/jpeg]
# Saving to: ‘/content/Test_Imgs/test_img1.jpg’
#
# /content/Test_Imgs/ 100%[===================>]  99.91K  --.-KB/s    in 0.007s
#
# 2022-12-19 08:15:20 (14.0 MB/s) - ‘/content/Test_Imgs/test_img1.jpg’ saved [102309/102309]

# %%
#https://appalshop.org/files/b2c6f79f/small/Mountain%20Farmer.jpg
# !wget https://appalshop.org/files/b2c6f79f/small/Mountain%20Farmer.jpg -O /content/Test_Imgs/test_img2.jpg
# Out:
# --2022-12-19 08:20:50--  https://appalshop.org/files/b2c6f79f/small/Mountain%20Farmer.jpg
# Resolving appalshop.org (appalshop.org)... 104.21.9.233, 172.67.131.14, 2606:4700:3030::ac43:830e, ...
# Connecting to appalshop.org (appalshop.org)|104.21.9.233|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn.gridprinciples.com/e6f/b2c6f79f/small.jpg [following]
# --2022-12-19 08:20:51--  https://cdn.gridprinciples.com/e6f/b2c6f79f/small.jpg
# Resolving cdn.gridprinciples.com (cdn.gridprinciples.com)... 104.21.81.41, 172.67.138.25, 2606:4700:3031::6815:5129, ...
# Connecting to cdn.gridprinciples.com (cdn.gridprinciples.com)|104.21.81.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184412 (180K) [image/jpeg]
# Saving to: ‘/content/Test_Imgs/test_img2.jpg’
#
# /content/Test_Imgs/ 100%[===================>] 180.09K   430KB/s    in 0.4s
#
# ...

# %%
#https://i.pinimg.com/550x/8e/07/8f/8e078f76d91dbc9c1476f9fa680eb34d.jpg
# !wget https://i.pinimg.com/550x/8e/07/8f/8e078f76d91dbc9c1476f9fa680eb34d.jpg -O /content/Test_Imgs/test_img3.jpg
# Out:
# --2022-12-19 08:23:38--  https://i.pinimg.com/550x/8e/07/8f/8e078f76d91dbc9c1476f9fa680eb34d.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 96.17.96.9, 96.17.96.11, 2600:1413:b000:1b::17d7:70e, ...
# Connecting to i.pinimg.com (i.pinimg.com)|96.17.96.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48098 (47K) [image/jpeg]
# Saving to: ‘/content/Test_Imgs/test_img3.jpg’
#
# /content/Test_Imgs/ 100%[===================>]  46.97K  --.-KB/s    in 0.003s
#
# 2022-12-19 08:23:38 (14.7 MB/s) - ‘/content/Test_Imgs/test_img3.jpg’ saved [48098/48098]

# %%
#https://i.pinimg.com/originals/f1/dd/4c/f1dd4ca98416ae0db5061587810e7fd5.jpg
# !wget https://i.pinimg.com/originals/f1/dd/4c/f1dd4ca98416ae0db5061587810e7fd5.jpg -O /content/Test_Imgs/test_img4.jpg
# Out:
# --2022-12-19 08:27:16--  https://i.pinimg.com/originals/f1/dd/4c/f1dd4ca98416ae0db5061587810e7fd5.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 96.17.96.9, 96.17.96.11, 2600:1413:b000:1b::17d7:70e, ...
# Connecting to i.pinimg.com (i.pinimg.com)|96.17.96.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53145 (52K) [image/jpeg]
# Saving to: ‘/content/Test_Imgs/test_img4.jpg’
#
# /content/Test_Imgs/ 100%[===================>]  51.90K  --.-KB/s    in 0.004s
#
# 2022-12-19 08:27:16 (13.6 MB/s) - ‘/content/Test_Imgs/test_img4.jpg’ saved [53145/53145]

# %%
# %cd /content/DeOldify
source_url = 'https://m.media-amazon.com/images/I/71h3KoyIMDL._AC_UF894,1000_QL80_.jpg' #@param {type:"string"}
render_factor = 35  #@param {type: "slider", min: 7, max: 40}
watermarked = True #@param {type:"boolean"}

if source_url is not None and source_url !='':
    image_path = colorizer.plot_transformed_image_from_url(url=source_url, render_factor=render_factor, compare=True, watermarked=watermarked)
    show_image_in_notebook(image_path)
else:
    print('Provide an image url and try again.')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
colorizer.plot_transformed_image('/content/Test_Imgs/test_img1.jpg', render_factor=35, display_render_factor=True, figsize=(8,8))
# Out:
# PosixPath('result_images/test_img1.jpg')

# %%
colorizer.plot_transformed_image('/content/Test_Imgs/test_img2.jpg', render_factor=35, display_render_factor=True, figsize=(8,8))
# Out:
# PosixPath('result_images/test_img2.jpg')

# %%
colorizer.plot_transformed_image('/content/Test_Imgs/test_img3.jpg', render_factor=35, display_render_factor=True, figsize=(10,10))
# Out:
# PosixPath('result_images/test_img3.jpg')

# %%
colorizer.plot_transformed_image('/content/Test_Imgs/test_img4.jpg', render_factor=35, display_render_factor=True, figsize=(10,10))
# Out:
# PosixPath('result_images/test_img4.jpg')
