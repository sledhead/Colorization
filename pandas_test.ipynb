# %%
import pandas as pd

label_keys = ['date','source_name','img_name','size','owner']


temp_list = []

for i_how_many in range(1,10):
  new_dict = {}

  for each_key in label_keys:
    new_dict[each_key] = new_val
  temp_list.append(new_dict)
