# %%
# !pwd
# %cd /content/sample_data
# Out:
# /content
# /content/sample_data

# %%
def csv_reader(file_name):
    file = open(file_name)
    result = file.read().split("\n")
    return result

# %%
def csv_reader(file_name):
    for row in open(file_name, "r"):
        yield row

# %%
csv_gen = csv_reader("mnist_test.csv")
row_count = 0

for row in csv_gen:
    row_count += 1

print(f"Row count is {row_count}")
# Out:
# Row count is 10000

# %%
def infinite_sequence():
    num = 0
    while True:
        yield num
        num += 1

# %%
gen = infinite_sequence()

print(gen)
# Out:
# <generator object infinite_sequence at 0x7f58d1d74eb0>

# %%
print(next(gen))

print(next(gen))

print(next(gen))

print(next(gen))
# Out:
# 5
# 6
# 7
# 8
